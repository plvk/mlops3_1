# %%
import eda

eda.perform_eda()
# Out:
# Data:
#         Income        Age         Loan  Loan to Income  Default
# 0  66155.92510  59.017015  8106.532131        0.122537        0
# 1  34415.15397  48.117153  6564.745018        0.190752        0
# 2  57317.17006  63.108049  8020.953296        0.139940        0
# 3  42709.53420  45.751972  6103.642260        0.142911        0
# 4  66952.68885  18.584336  8770.099235        0.130990        1
#
# Missing Values Analysis:
# Нет пропущенных значений в датафрейме.
#
# Plotting pairwise distribution diagrams:
# Correlation analysis:
# Class balance analysis:

# %% [markdown]
# Датасет содержит информацию о клиентах банка, их доходах, возрасте, сумме кредита и информацию о дефолте.
#
# Колонки:
#
# Income — годовой доход клиента.
#
# Age — возраст клиента.
#
# Loan — сумма кредита.
#
# Loan to Income — отношение суммы кредита к доходу.
#
# Default — бинарный таргет (1 = дефолт, 0 = нет).
#
# Заключение и выводы
#
# 1. Анализ пропущенные значений.
# Пропущенных значений не было обнаружено в датасете.
#
# 2. Анализ диаграмм попарного распределения признаков.
# Из графиков видно, что дефолт чаще происходил у людей до 40 лет и с суммой кредита от 4000.
# Для сумм кредита до 2500 дефолт не наблюдается.
#
# 3. Корреляционный анализ.
# Корреляционный анализ показал, что существует умеренная положительная корреляция между доходом и суммой кредита,
# а также отношением суммы кредита к доходу клиента и суммой кредита.
#
# 4. Анализ распределения классов.
# Не дефолт значительно преобладает по сравнению с дефолтом.
